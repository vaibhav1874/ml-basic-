# %% [markdown]
# # Exploratory Data Analysis (EDA)\n
# This notebook loads the insurance dataset, performs basic statistics, and visualizes relationships.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")


df = pd.read_csv("insurance.csv")
print(df)
